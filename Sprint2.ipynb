# %%
from matplotlib import pyplot as plt
from matplotlib import style

style.use('ggplot')
 
x = ['Simba', 'Lays', 'Doritoes', 'Pringles', 'Stylos',]
y =[16.20, 18.00, 15.00, 21.0, 1.00]

plt.bar(x, y, align='center')

plt.title('Chips price comparison')
plt.ylabel('Price list of chips in Rands')
plt.xlabel('types of chips')
plt.show()

# %%
import pandas as pd
from matplotlib import pyplot as plt

x = ['Coke', 'Fanta', 'Stoney', 'Sprite', 'Sparlet',]
y = [20.20, 20.00, 20.00, 20.0, 13.00]
plt.plot(x, y)
#adding title to the graph
plt.title("Cold Drinks prices")
#putting the x and y labels
plt.xlabel("Types of drinks")
plt.ylabel("Price list of Drinks")
#adding legend sentence on the graph
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
import MySQLdb
import matplotlib.pyplot as plt
import pandas as pd
import pymysql
import sqlalchemy

conn=sqlalchemy.create_engine("mysql+pymysql://root:Sanelisiwe2000@localhost/world")

df=pd.read_sql_table("sprint",conn)
 
df
# Out:
#          Type   Products Prices Quantity
# 0       Chips    Doritos     15       20
# 1                   Lays     12       15
# 2                NikNaks      5       30
# 3                  Simba     18       18
# 4
# 5   Cooldrink      Fanta     11       10
# 6                 Sprite     14       10
# 7                   Jive     10       20
# 8                  Score     10       15
# 9
# 10  Chocolate         Ps      8       20
# 11                KitKat     10       15
# 12               Bar-one     13       10
# 13                   Tex      7       25
# 14
# 15       Pies    Chicken     15       13
# 16                Burger     20       10
# 17                 steak     18       20
# 18                pepper     15       10
# 19
# 20      Fruit      Guava     10       20
# 21                 Peach     12       15
# 22                  Pear      8       30
# 23                Banana     15       10
# 24
# 25   Cupcakes    Vanilla     20       20
# 26              Chocmint     17       20
# 27                Browny     22       15
# 28             Chocolate     20       10
# 29
# 30    Veggies   Potatoes     25       10
# 31               Spinach     15       10
# 32                 Onion     10       10
# 33             Butternut     12       10

# %%
import pandas as pd
from matplotlib import pyplot as plt

x =df['Products']
y =df['Prices']

plt.bar(x, y)
plt.title("All Products")
plt.xlabel("Products", fontsize= 30,)
plt.ylabel("Prices", fontsize= 30, )


plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
from matplotlib import pyplot as plt
data={'Pepper Steak':15, 'Chicken':15, 'Burger':20, 'Steak':18, }
Products = list(data.keys())
Prices = list(data.values())

fig, axis = plt.subplot(  figsize= (15, 3, 4), sharey=True)
axis[0].bar(Products, Prices)
axis[1].scatter(Products, Prices)
axis[2].plot(Products, Prices)

fig.suptitle('Categorical Plotting')

plt.show
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-1c0979d2b023> in <module>
#       4 Prices = list(data.values())
#       5
# ----> 6 fig, axis = plt.subplot(  figsize= (15, 3, 4), sharey=True)
#       7 axis[0].bar(Products, Prices)
#       8 axis[1].scatter(Products, Prices)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\pyplot.py in subplot(*args, **kwargs)
#    1074
#    1075     fig = gcf()
# -> 1076     a = fig.add_subplot(*args, **kwargs)
#    1077     bbox = a.bbox
#    1078     byebye = []
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\figure.py in add_subplot(self, *args, **kwargs)
#    1412                     self._axstack.remove(ax)
#    1413
# -> 1414             a = subplot_class_factory(projection_class)(self, *args, **kwargs)
#    1415
#    1416         return self._add_axes_internal(key, a)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\axes\_subplots.py in __init__(self, fig, *args, **kwargs)
#      67
#      68         # _axes_class is set in the subplot_class_factory
# ---> 69         self._axes_class.__init__(self, fig, self.figbox, **kwargs)
#      70         # add a layout box to this, for both the full axis, and the poss
#      71         # of the axis.  We need both because the axes may become smaller
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\axes\_base.py in __init__(self, fig, rect, facecolor, frameon, sharex, sharey, label, xscale, yscale, **kwargs)
#     475             self._shared_x_axes.join(self, sharex)
#     476         if sharey is not None:
# --> 477             self._shared_y_axes.join(self, sharey)
#     478         self.set_label(label)
#     479         self.set_figure(fig)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\cbook\__init__.py in join(self, a, *args)
#     933
#     934         for arg in args:
# --> 935             set_b = mapping.get(weakref.ref(arg), [weakref.ref(arg)])
#     936             if set_b is not set_a:
#     937                 if len(set_b) > len(set_a):
#
# TypeError: cannot create weak reference to 'bool' object
